# %%
import pandas as pd
from  pandasql import  sqldf
AF_HOME = '/home/ec2-user/airflow/dags/'

# %%
df = pd.read_csv(f'{AF_HOME}10000-Sales-Records.zip')

# %%
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
df.columns = [x.replace(' ','_') for x in df.columns]

# %%
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item_Type Sales_Channel Order_Priority  Order_Date   Order_ID  \
# ...

# %%
df.to_csv(f'{AF_HOME}tmp_10000-Sales-Records.csv')

# %%
df = pd.read_csv(f'{AF_HOME}tmp_10000-Sales-Records.csv')
sqldf('select Region,Country, max(Total_Revenue) max,avg(Total_Revenue) avg from df group by 1,2 ')
# Out:
#                  Region     Country         max           avg
# 0                  Asia  Bangladesh  6441769.32  1.545815e+06
# 1                  Asia      Bhutan  5831324.02  1.284843e+06
# 2                  Asia      Brunei  6680026.92  1.606356e+06
# 3                  Asia    Cambodia  5072925.90  1.253570e+06
# 4                  Asia       China  6501029.43  1.446507e+06
# ..                  ...         ...         ...           ...
# 180  Sub-Saharan Africa  The Gambia  6570430.64  1.413980e+06
# 181  Sub-Saharan Africa        Togo  5628408.03  1.170420e+06
# 182  Sub-Saharan Africa      Uganda  5043433.69  1.516481e+06
# 183  Sub-Saharan Africa      Zambia  6484749.18  1.378238e+06
# 184  Sub-Saharan Africa    Zimbabwe  5228565.09  1.059200e+06
#
# [185 rows x 4 columns]

# %%
_.to_csv(f'{AF_HOME}10000-Sales-Records_agg.csv',index=False)
