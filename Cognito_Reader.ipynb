# %%
import boto3
import pandas as pd
import awswrangler as wr

# %%
UserPoolId = "ap-southeast-2_NNQ7ZpKrB" # user pool id for: prod_inspection_app_user_pool

# %%
def get_all_users():
    cognito = boto3.client('cognito-idp')
    
    users = []
    next_page = None
    kwargs = {
        'UserPoolId': UserPoolId
    }
    
    users_remain = True
    while(users_remain):
        if next_page:
            kwargs['PaginationToken'] = next_page
        response = cognito.list_users(**kwargs)
        users.extend(response['Users'])
        next_page = response.get('PaginationToken', None)
        users_remain = next_page is not None

    return users

# %%
users = get_all_users()
users
# Out:
# [{'Username': '2584f3e5-1e00-4a8d-b67a-fdedeab9f42d',
#   'Attributes': [{'Name': 'sub',
#     'Value': '2584f3e5-1e00-4a8d-b67a-fdedeab9f42d'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'Inspector'},
#    {'Name': 'family_name', 'Value': 'Five'},
#    {'Name': 'email', 'Value': 'inspector5@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[Inspectors]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 7, 21, 49, 43, 225000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 3, 7, 21, 58, 44, 20000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': '278310af-918f-4ca5-a558-2be1751d5389',
#   'Attributes': [{'Name': 'sub',
#     'Value': '278310af-918f-4ca5-a558-2be1751d5389'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'Inspector'},
#    {'Name': 'family_name', 'Value': 'Third'},
#    {'Name': 'email', 'Value': 'inspector3@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[Inspectors]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 7, 21, 48, 19, 153000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 3, 7, 21, 56, 45, 315000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': '28b64e95-afbe-454f-ba64-2637aa9c8b4e',
#   'Attributes': [{'Name': 'sub',
#     'Value': '28b64e95-afbe-454f-ba64-2637aa9c8b4e'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'Inspector'},
#    {'Name': 'family_name', 'Value': 'Second'},
#    {'Name': 'email', 'Value': 'inspector2@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[Inspectors]'}],
#   'UserCreateDate': datetime.datetime(2022, 2, 23, 10, 21, 2, 750000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 2, 23, 10, 29, 13, 638000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': '4397d035-339b-40ba-a269-a0a9d26b8d1e',
#   'Attributes': [{'Name': 'sub',
#     'Value': '4397d035-339b-40ba-a269-a0a9d26b8d1e'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'Inspector'},
#    {'Name': 'family_name', 'Value': 'First'},
#    {'Name': 'email', 'Value': 'inspector1@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[Inspectors]'}],
#   'UserCreateDate': datetime.datetime(2022, 2, 23, 10, 16, 1, 998000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 2, 23, 10, 28, 27, 713000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': '468724be-6389-441f-ae0a-5bfd357f6ae0',
#   'Attributes': [{'Name': 'sub',
#     'Value': '468724be-6389-441f-ae0a-5bfd357f6ae0'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'Inspector'},
#    {'Name': 'family_name', 'Value': 'Four'},
#    {'Name': 'email', 'Value': 'inspector4@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[Inspectors]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 7, 21, 49, 26, 793000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 3, 7, 21, 57, 56, 34000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': '986ef82f-76a2-44bd-bbdb-8e865be786d3',
#   'Attributes': [{'Name': 'sub',
#     'Value': '986ef82f-76a2-44bd-bbdb-8e865be786d3'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'Inspector'},
#    {'Name': 'family_name', 'Value': 'Seven'},
#    {'Name': 'email', 'Value': 'inspector7@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[Inspectors]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 7, 21, 50, 40, 618000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 3, 7, 22, 1, 7, 451000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': 'c0047dc2-ffe5-4f3d-abd5-37727e08e90c',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'c0047dc2-ffe5-4f3d-abd5-37727e08e90c'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'Inspector'},
#    {'Name': 'family_name', 'Value': 'Six'},
#    {'Name': 'email', 'Value': 'inspector6@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[Inspectors]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 7, 21, 50, 5, 421000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 3, 7, 22, 0, 30, 924000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': 'c94cf324-4c30-42bc-bd37-9e0911f4b9d4',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'c94cf324-4c30-42bc-bd37-9e0911f4b9d4'},
#    {'Name': 'email_verified', 'Value': 'true'},
#    {'Name': 'given_name', 'Value': 'QAManager'},
#    {'Name': 'family_name', 'Value': 'Eight'},
#    {'Name': 'email', 'Value': 'qamanager@aiolatyson.com'},
#    {'Name': 'custom:groups', 'Value': '[QAManagers]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 7, 21, 50, 56, 758000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 4, 4, 15, 16, 41, 908000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'CONFIRMED'},
#  {'Username': 'prod-tyson-okta_annemarie.cunningham@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'efeac4c4-082b-43ab-8fb7-402758080747'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"ANNEMARIE.CUNNINGHAM@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1660518613212}]'},
#    {'Name': 'given_name', 'Value': 'ANNE MARIE'},
#    {'Name': 'family_name', 'Value': 'Cunningham'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 8, 14, 23, 10, 13, 224000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 14, 23, 10, 13, 224000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_brendlesly.ojeda@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'f01f0496-8c52-43a6-9ef5-38670996396f'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"Brendlesly.Ojeda@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1650480189876}]'},
#    {'Name': 'given_name', 'Value': 'BRENDSLEY'},
#    {'Name': 'family_name', 'Value': 'OJEDA'},
#    {'Name': 'custom:groups',
#     'Value': '[Team Member_aiOLA, Team Supervisor_Aiola]'}],
#   'UserCreateDate': datetime.datetime(2022, 4, 20, 18, 43, 9, 896000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 9, 18, 30, 52, 881000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_craig.hindson@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'ffa2147b-a57e-4f87-a100-ddc0ded900ce'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"Craig.Hindson@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exk15tasr92pK2QJX0h8","primary":true,"dateCreated":1646357133540}]'},
#    {'Name': 'given_name', 'Value': 'CRAIG'},
#    {'Name': 'family_name', 'Value': 'HINDSON'},
#    {'Name': 'custom:groups',
#     'Value': '[Team Member_aiOLA, Team Supervisor_Aiola]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 4, 1, 25, 33, 551000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 7, 13, 1, 31, 46, 171000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_idpro-venkateshreddy.irigela@adm.local',
#   'Attributes': [{'Name': 'sub',
#     'Value': '04b8e7bd-b037-4ec7-bf71-c9afeaf27c4a'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"idpro-venkateshreddy.irigela@adm.local","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1653990660381}]'},
#    {'Name': 'given_name', 'Value': 'venkateshreddy'},
#    {'Name': 'family_name', 'Value': 'irigela'},
#    {'Name': 'custom:groups', 'Value': 'Team Supervisor_Aiola'}],
#   'UserCreateDate': datetime.datetime(2022, 5, 31, 9, 51, 0, 392000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 5, 31, 9, 51, 0, 392000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_k26-00001801@tsnid.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': '13f0d123-2299-4d2b-90ac-82767b341593'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"K26-00001801@tsnid.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1650911502454}]'},
#    {'Name': 'given_name', 'Value': 'KIMBERLEY'},
#    {'Name': 'family_name', 'Value': 'HUTCHINS'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 4, 25, 18, 31, 42, 466000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 5, 18, 34, 49, 316000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_k26-00002000@tsnid.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'cbc7a162-0a0e-4bfb-b7c2-4171f1ecc572'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"K26-00002000@tsnid.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1648751606300}]'},
#    {'Name': 'given_name', 'Value': 'SHARNA'},
#    {'Name': 'family_name', 'Value': 'BIRT'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 31, 18, 33, 26, 310000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 2, 18, 34, 8, 986000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_k26-00002255@tsnid.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': '8e982d88-6546-40b6-b638-905c7b7a022e'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"k26-00002255@tsnid.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1659551741609}]'},
#    {'Name': 'given_name', 'Value': 'Jorden'},
#    {'Name': 'family_name', 'Value': 'Molloy'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 8, 3, 18, 35, 41, 634000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 11, 18, 33, 25, 435000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_k26-00002262@tsnid.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'd57ad2bb-d74a-4ed4-b26d-1d6d1ace47cd'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"k26-00002262@tsnid.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1660503603752}]'},
#    {'Name': 'given_name', 'Value': 'Stephanie'},
#    {'Name': 'family_name', 'Value': 'Tyler'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 8, 14, 19, 0, 3, 765000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 14, 19, 0, 3, 765000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_k26-00002339@tsnid.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': '3356bda0-5687-4892-a208-0fddbaa2d972'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"K26-00002339@tsnid.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1656613912848}]'},
#    {'Name': 'given_name', 'Value': 'Jacinta'},
#    {'Name': 'family_name', 'Value': 'Robert'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 6, 30, 18, 31, 52, 859000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 11, 18, 57, 55, 793000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_k26-00006119@tsnid.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'c7533c6c-5a8d-440a-aa93-fd9ba9cf3afe'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"K26-00006119@tsnid.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1648751564633}]'},
#    {'Name': 'given_name', 'Value': 'Samantha'},
#    {'Name': 'family_name', 'Value': 'Wilshire'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 31, 18, 32, 44, 645000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 5, 4, 18, 44, 25, 176000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_kylie.larbalestier@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': '86a90d49-ee0c-42e9-a077-2ef8ff38c82a'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"Kylie.Larbalestier@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1649107601735}]'},
#    {'Name': 'given_name', 'Value': 'KYLIE'},
#    {'Name': 'family_name', 'Value': 'LARBALESTIER'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 4, 4, 21, 26, 41, 745000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 7, 19, 20, 18, 25, 592000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_narelle.stewart@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': '2b76740a-ab3e-416d-b50a-61f5bffc6643'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"Narelle.Stewart@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1648447594499}]'},
#    {'Name': 'given_name', 'Value': 'NARELLE'},
#    {'Name': 'family_name', 'Value': 'STEWART'},
#    {'Name': 'custom:groups', 'Value': 'Team Member_aiOLA'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 28, 6, 6, 34, 510000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 7, 14, 3, 12, 38, 500000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_oren.ben-meir@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': '29ef6b5e-8e23-449e-9dcc-5c05d8f9defa'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"Oren.Ben-Meir@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1648543118591}]'},
#    {'Name': 'given_name', 'Value': 'Oren'},
#    {'Name': 'family_name', 'Value': 'Ben-Meir'},
#    {'Name': 'custom:groups',
#     'Value': '[Team Member_aiOLA, Team Supervisor_Aiola]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 29, 8, 38, 38, 590000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 6, 9, 12, 23, 8, 586000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_shannon.nixon@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'ee77fdad-0192-482d-9f41-e56e535e4eb6'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"SHANNON.NIXON@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1648680801712}]'},
#    {'Name': 'given_name', 'Value': 'SHANNON'},
#    {'Name': 'family_name', 'Value': 'NIXON'},
#    {'Name': 'custom:groups',
#     'Value': '[Team Member_aiOLA, Team Supervisor_Aiola]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 30, 22, 53, 21, 726000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 14, 22, 56, 30, 443000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'},
#  {'Username': 'prod-tyson-okta_tanya.mcerlean@tyson.com',
#   'Attributes': [{'Name': 'sub',
#     'Value': 'eb5ac545-9e77-49ce-9a90-a806c0605f79'},
#    {'Name': 'identities',
#     'Value': '[{"userId":"Tanya.McErlean@tyson.com","providerName":"prod-tyson-okta","providerType":"SAML","issuer":"http://www.okta.com/exkgir733xeofinCR357","primary":true,"dateCreated":1648292106172}]'},
#    {'Name': 'given_name', 'Value': 'TANYA'},
#    {'Name': 'family_name', 'Value': 'MCERLEAN'},
#    {'Name': 'custom:groups',
#     'Value': '[Team Member_aiOLA, Team Supervisor_Aiola, Team Management_aiola]'}],
#   'UserCreateDate': datetime.datetime(2022, 3, 26, 10, 55, 6, 183000, tzinfo=tzlocal()),
#   'UserLastModifiedDate': datetime.datetime(2022, 8, 4, 0, 24, 21, 601000, tzinfo=tzlocal()),
#   'Enabled': True,
#   'UserStatus': 'EXTERNAL_PROVIDER'}]

# %%
len(users)
# Out:
# 23

# %%
uuid =[]
given_name = []
family_name = []

for i in range(len(users)):
    
    # first extraction: uuid
    single_uuid = list(users[i]['Attributes'][0].values())[1]
    uuid.append(single_uuid)
    
    # second extraction: given name
    single_given_name = list(users[i]['Attributes'][2].values())[1]
    given_name.append(single_given_name)
    
    # third extraction family_name
    single_family_name = list(users[i]['Attributes'][3].values())[1]
    family_name.append(single_family_name)

# %%
df_users = pd.DataFrame()

# insert the data from cognito into the df_users dataframe
df_users['uuid'] = uuid
df_users['given_name'] = given_name
df_users['family_name'] = family_name
df_users['user_name'] = df_users['given_name'] + ' ' + df_users['family_name']

df_users
# Out:
#                                     uuid      given_name   family_name  \
# 0   2584f3e5-1e00-4a8d-b67a-fdedeab9f42d       Inspector          Five
# 1   278310af-918f-4ca5-a558-2be1751d5389       Inspector         Third
# 2   28b64e95-afbe-454f-ba64-2637aa9c8b4e       Inspector        Second
# 3   4397d035-339b-40ba-a269-a0a9d26b8d1e       Inspector         First
# 4   468724be-6389-441f-ae0a-5bfd357f6ae0       Inspector          Four
# 5   986ef82f-76a2-44bd-bbdb-8e865be786d3       Inspector         Seven
# 6   c0047dc2-ffe5-4f3d-abd5-37727e08e90c       Inspector           Six
# 7   c94cf324-4c30-42bc-bd37-9e0911f4b9d4       QAManager         Eight
# 8   efeac4c4-082b-43ab-8fb7-402758080747      ANNE MARIE    Cunningham
# 9   f01f0496-8c52-43a6-9ef5-38670996396f       BRENDSLEY         OJEDA
# 10  ffa2147b-a57e-4f87-a100-ddc0ded900ce           CRAIG       HINDSON
# 11  04b8e7bd-b037-4ec7-bf71-c9afeaf27c4a  venkateshreddy       irigela
# 12  13f0d123-2299-4d2b-90ac-82767b341593       KIMBERLEY      HUTCHINS
# 13  cbc7a162-0a0e-4bfb-b7c2-4171f1ecc572          SHARNA          BIRT
# 14  8e982d88-6546-40b6-b638-905c7b7a022e          Jorden        Molloy
# 15  d57ad2bb-d74a-4ed4-b26d-1d6d1ace47cd       Stephanie         Tyler
# 16  3356bda0-5687-4892-a208-0fddbaa2d972         Jacinta        Robert
# 17  c7533c6c-5a8d-440a-aa93-fd9ba9cf3afe        Samantha      Wilshire
# 18  86a90d49-ee0c-42e9-a077-2ef8ff38c82a           KYLIE  LARBALESTIER
# 19  2b76740a-ab3e-416d-b50a-61f5bffc6643         NARELLE       STEWART
# 20  29ef6b5e-8e23-449e-9dcc-5c05d8f9defa            Oren      Ben-Meir
# 21  ee77fdad-0192-482d-9f41-e56e535e4eb6         SHANNON         NIXON
# 22  eb5ac545-9e77-49ce-9a90-a806c0605f79           TANYA      MCERLEAN
#
#                  user_name
# 0           Inspector Five
# 1          Inspector Third
# 2         Inspector Second
# 3          Inspector First
# 4           Inspector Four
# 5          Inspector Seven
# 6            Inspector Six
# 7          QAManager Eight
# 8    ANNE MARIE Cunningham
# 9          BRENDSLEY OJEDA
# 10           CRAIG HINDSON
# 11  venkateshreddy irigela
# 12      KIMBERLEY HUTCHINS
# 13             SHARNA BIRT
# 14           Jorden Molloy
# 15         Stephanie Tyler
# 16          Jacinta Robert
# 17       Samantha Wilshire
# 18      KYLIE LARBALESTIER
# 19         NARELLE STEWART
# 20           Oren Ben-Meir
# 21           SHANNON NIXON
# 22          TANYA MCERLEAN

# %%
wr.s3.to_parquet(
    df = df_users.loc[:, ('uuid', 'user_name')],
    path='s3://aiola-777622251240-ap-southeast-2-data/users_data/',
    dataset=True,
    database='inspection-app',  # Athena/Glue database
    table='inspectors_from_cognito',  # Athena/Glue table
    dtype={'uuid': 'string',
           'user_name':'string'},
    mode = 'overwrite'
)
# Out:
# {'paths': ['s3://aiola-777622251240-ap-southeast-2-data/users_data/d334106509584b70883091891db61690.snappy.parquet'],
#  'partitions_values': {}}

# %%
df_users.loc[:, ('uuid', 'user_name')]
# Out:
#                                     uuid               user_name
# 0   2584f3e5-1e00-4a8d-b67a-fdedeab9f42d          Inspector Five
# 1   278310af-918f-4ca5-a558-2be1751d5389         Inspector Third
# 2   28b64e95-afbe-454f-ba64-2637aa9c8b4e        Inspector Second
# 3   4397d035-339b-40ba-a269-a0a9d26b8d1e         Inspector First
# 4   468724be-6389-441f-ae0a-5bfd357f6ae0          Inspector Four
# 5   986ef82f-76a2-44bd-bbdb-8e865be786d3         Inspector Seven
# 6   c0047dc2-ffe5-4f3d-abd5-37727e08e90c           Inspector Six
# 7   c94cf324-4c30-42bc-bd37-9e0911f4b9d4         QAManager Eight
# 8   efeac4c4-082b-43ab-8fb7-402758080747   ANNE MARIE Cunningham
# 9   f01f0496-8c52-43a6-9ef5-38670996396f         BRENDSLEY OJEDA
# 10  ffa2147b-a57e-4f87-a100-ddc0ded900ce           CRAIG HINDSON
# 11  04b8e7bd-b037-4ec7-bf71-c9afeaf27c4a  venkateshreddy irigela
# 12  13f0d123-2299-4d2b-90ac-82767b341593      KIMBERLEY HUTCHINS
# 13  cbc7a162-0a0e-4bfb-b7c2-4171f1ecc572             SHARNA BIRT
# 14  8e982d88-6546-40b6-b638-905c7b7a022e           Jorden Molloy
# 15  d57ad2bb-d74a-4ed4-b26d-1d6d1ace47cd         Stephanie Tyler
# 16  3356bda0-5687-4892-a208-0fddbaa2d972          Jacinta Robert
# 17  c7533c6c-5a8d-440a-aa93-fd9ba9cf3afe       Samantha Wilshire
# 18  86a90d49-ee0c-42e9-a077-2ef8ff38c82a      KYLIE LARBALESTIER
# 19  2b76740a-ab3e-416d-b50a-61f5bffc6643         NARELLE STEWART
# 20  29ef6b5e-8e23-449e-9dcc-5c05d8f9defa           Oren Ben-Meir
# 21  ee77fdad-0192-482d-9f41-e56e535e4eb6           SHANNON NIXON
# 22  eb5ac545-9e77-49ce-9a90-a806c0605f79          TANYA MCERLEAN
